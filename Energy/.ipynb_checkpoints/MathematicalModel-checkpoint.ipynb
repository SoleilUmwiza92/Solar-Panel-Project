# %% [markdown]
# ## In this notebook, I explore a mathematical model to identify which parameter(s) have the greatest impact on solar panel yield.

# %%
# Only run this once to install packages
# !pip install pandas matplotlib numpy pvlib requests knmy
# Out:
# Requirement already satisfied: pandas in c:\users\csten\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\csten\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy in c:\users\csten\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pvlib in c:\users\csten\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: requests in c:\users\csten\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: knmy in c:\users\csten\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\csten\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\csten\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\csten\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\csten\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\csten\anaconda3\lib\site-packages (from pvlib) (1.13.1)
# Requirement already satisfied: h5py in c:\users\csten\anaconda3\lib\site-packages (from pvlib) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\csten\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\csten\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\csten\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\csten\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: sphinx in c:\users\csten\anaconda3\lib\site-packages (from knmy) (7.3.7)
# Requirement already satisfied: sphinx_rtd_theme in c:\users\csten\anaconda3\lib\site-packages (from knmy) (3.0.2)
# Requirement already satisfied: pytest in c:\users\csten\anaconda3\lib\site-packages (from knmy) (7.4.4)
# Requirement already satisfied: setuptools in c:\users\csten\anaconda3\lib\site-packages (from knmy) (75.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\csten\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: iniconfig in c:\users\csten\anaconda3\lib\site-packages (from pytest->knmy) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\csten\anaconda3\lib\site-packages (from pytest->knmy) (1.0.0)
# Requirement already satisfied: colorama in c:\users\csten\anaconda3\lib\site-packages (from pytest->knmy) (0.4.6)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.0.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (3.1.4)
# Requirement already satisfied: Pygments>=2.14 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (2.15.1)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (0.18.1)
# Requirement already satisfied: snowballstemmer>=2.0 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (2.2.0)
# Requirement already satisfied: babel>=2.9 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (2.11.0)
# Requirement already satisfied: alabaster~=0.7.14 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in c:\users\csten\anaconda3\lib\site-packages (from sphinx->knmy) (1.4.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in c:\users\csten\anaconda3\lib\site-packages (from sphinx_rtd_theme->knmy) (4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\csten\anaconda3\lib\site-packages (from Jinja2>=3.0->sphinx->knmy) (2.1.3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests, urllib, urllib3, time, warnings
from pvlib.solarposition import get_solarposition
from pvlib import irradiance
from matplotlib.collections import PolyCollection
import knmy
import seaborn as sns

plt.close('all')
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Define Configs and Month Lookup

# %%
# Month dictionary
number_to_month = {
    1 : ['January', 31], 2 : ['February', 28], 3 : ['March', 31],
    4 : ['April', 30],   5 : ['May', 31],       6 : ['June', 30],
    7 : ['July', 31],    8 : ['August', 31],    9 : ['September', 30],
    10: ['October', 31], 11: ['November', 30], 12: ['December', 31]
}

# %%
class Color:
    W       = '\033[0m'
    R       = '\033[1;31;48m'
    G       = '\033[32m'
    B       = '\033[34m'
    O       = '\033[33m'
    LB      = '\033[1;34;48m'
    P       = '\033[35m'
    C       = '\033[36m'
    WBLACK  = '\033[1;37;40m'
    WBLUE   = '\033[1;37;44m'
    END     = '\033[1;37;0m'
    WR      = '\033[1;37;41m'
    BG      = '\033[1;40;42m'

# %% [markdown]
# ## Load KNMI Weather Data

# %%
# url = 'https://www.knmi.nl/nederland-nu/klimatologie/uurgegevens'
print(Color.R + 'loading KNMI data from file ...' + Color.END)
df = pd.read_csv('df_KNMI.csv')
df.head()
# Out:
# loading KNMI data from file ...
#    Unnamed: 0  STN  YYYYMMDD  HH   DD   FH   FF   FX   T  T10N  TD  Q  SQ  VV  \
# 0           0  330  20240101   1  210  120  120  180  75   NaN  61  0   0 NaN
# 1           1  330  20240101   2  210   90  100  150  74   NaN  62  0   0 NaN
# 2           2  330  20240101   3  240  100  110  160  92   NaN  59  0   0 NaN
# 3           3  330  20240101   4  240  110  110  190  91   NaN  59  0   0 NaN
# 4           4  330  20240101   5  240  100  100  150  95   NaN  54  0   0 NaN
#
#     N   U     P
# 0 NaN  91  9951
# 1 NaN  91  9958
# 2 NaN  79  9959
# 3 NaN  80  9966
# 4 NaN  76  9973

# %%
# Date formatting
df['HH'] = df['HH'].astype(str).str.zfill(2)
df['YYYYMMDDHH'] = pd.to_datetime(df['YYYYMMDD'].astype(str) + df['HH'], format='%Y%m%d%H', errors='coerce')
df['YYYYMMDDHH'] = np.where(df['YYYYMMDDHH'].dt.strftime('%H:%M') == '00:00',
                            df['YYYYMMDDHH'] + pd.DateOffset(days=1), df['YYYYMMDDHH'])

# %%
drop_columns = ['YYYYMMDD', 'HH', 'DD', 'T10N', 'TD', 'VV', 'STN']
df = df.drop(columns = drop_columns)
df.insert(0, 'YYYYMMDDHH', df.pop('YYYYMMDDHH'))
print(df.head())
# Out:
#            YYYYMMDDHH  Unnamed: 0   FH   FF   FX   T  Q  SQ   N   U     P
# 0 2024-01-01 01:00:00           0  120  120  180  75  0   0 NaN  91  9951
# 1 2024-01-01 02:00:00           1   90  100  150  74  0   0 NaN  91  9958
# 2 2024-01-01 03:00:00           2  100  110  160  92  0   0 NaN  79  9959
# 3 2024-01-01 04:00:00           3  110  110  190  91  0   0 NaN  80  9966
# 4 2024-01-01 05:00:00           4  100  100  150  95  0   0 NaN  76  9973

# %%
# New column names 
new_column_names = { 
    'FH' : 'average windspeed (m/s)',
    'FF' : 'windspeed previous 10 minuten (m/s)',
    'FX' : 'highest windspeed (m/s)',
    'T'  : 'temperature in degrees Celcius',
    'SQ' : 'duration of sunshine (h)',
    'Q'  : 'global radiation (in J/m^2)',    
    'P'  : 'air pressure (Pa)',
    'N'  : 'cloud cover (-)',
    'U'  : 'relative humidity (in percentages)'
}
df = df.rename(columns = new_column_names)

# %%
df.head()
# Out:
#            YYYYMMDDHH  Unnamed: 0  average windspeed (m/s)  \
# 0 2024-01-01 01:00:00           0                      120
# 1 2024-01-01 02:00:00           1                       90
# 2 2024-01-01 03:00:00           2                      100
# 3 2024-01-01 04:00:00           3                      110
# 4 2024-01-01 05:00:00           4                      100
#
#    windspeed previous 10 minuten (m/s)  highest windspeed (m/s)  \
# 0                                  120                      180
# 1                                  100                      150
# 2                                  110                      160
# 3                                  110                      190
# 4                                  100                      150
#
#    temperature in degrees Celcius  global radiation (in J/m^2)  \
# 0                              75                            0
# 1                              74                            0
# 2                              92                            0
# 3                              91                            0
# 4                              95                            0
#
#    duration of sunshine (h)  cloud cover (-)  \
# 0                         0              NaN
# 1                         0              NaN
# 2                         0              NaN
# 3                         0              NaN
# 4                         0              NaN
#
#    relative humidity (in percentages)  air pressure (Pa)
# 0                                  91               9951
# 1                                  91               9958
# 2                                  79               9959
# 3                                  80               9966
# 4                                  76               9973

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
# Group variables
windvariabelen = ['average windspeed (m/s)',
                  'windspeed previous 10 minuten (m/s)', 
                  'highest windspeed (m/s)' ]
temperature_variables = ['temperature in degrees Celcius'],
air_pressurevariabelen = ['air pressure (Pa)']
zonvariabelen = ['duration of sunshine (h)', 'global radiation (in J/m^2)']

# Physical constants
area_of_solar_panel = 2.45         ## area of one module [m^2]
efficiency_solar_panel = 0.20  ## efficiency of one solar panel [-]
number_of_solar_panels = 2    ## total number of solar panels used [-]
lat = 51.96811434560797             ## latitude of plant
lon = 4.095795682209092             ## longitude of plant
module = \
    {'theta_M': np.deg2rad(20),
     'azimuth': np.deg2rad(115)}

# Convert to S.I. units
for column in zonvariabelen:
    if column == 'duration of sunshine (h)':
        df[column] *= 0.10
    elif column == 'global radiation (in J/m^2)':
        df[column] *= 1e4

# %%
# Get the elevation of the module
def make_remote_request(url: str, params: dict):
    global response
    while True:
        try:
            response = requests.get(url + urllib.parse.urlencode(params))
        except (OSError, urllib3.exceptions.ProtocolError) as error:
            print(error)
            continue
        break

    return response

def elevation_function(lat, lon):
    url = 'https://api.opentopodata.org/v1/eudem25m?'
    params = {'locations': f"{lat},{lon}"}
    result = make_remote_request(url, params)
    if 'results' in result.json().keys():
        return_value = result.json()['results'][0]['elevation']
    else:
        return_value = None
    return return_value

# %%
elevation_module = elevation_function(lat, lon)
while elevation_module == None:
    time.sleep(0.40)
    elevation_module = elevation_function(lat, lon)

# %%
# Calculate the positions of the sun
date_time_or_doy = df['YYYYMMDDHH'] 
solpos = get_solarposition(
    time = date_time_or_doy, latitude = lat,
    longitude = lon, altitude = elevation_module,
    pressure = df['air pressure (Pa)'].values, 
    temperature = df['temperature in degrees Celcius'].values)

# %%
# Orientation parameters
theta_M = module['theta_M']                     ## tilt angle module
az_M = module['azimuth']                        ## azimuth angle module

# Compute G_module, first decompose the ghi into dni and dhi
ghi = df['global radiation (in J/m^2)'].values  ## global horizontal irradiance in [J/m^2]
out_erbs = irradiance.erbs(ghi, solpos.zenith, solpos.index)
out_erbs = out_erbs.rename(columns = {'dni': 'dni_erbs', 'dhi': 'dhi_erbs'})
dni = out_erbs['dni_erbs'].values               ## direct normal irradiance. [J/m^2]
dhi = out_erbs['dhi_erbs'].values               ## diffuse horizontal irradiance in [J/m^2]
sky_model = 'isotropic'
poa = irradiance.get_total_irradiance(np.rad2deg(theta_M), np.rad2deg(az_M),
                         solpos.zenith, solpos.azimuth,
                         dni, ghi, dhi, dni_extra = None, airmass = None,
                         surface_type = 'sea',
                         model = sky_model)
G_module = poa['poa_global'].values

# %%
# Store into the dataframe
df['yield solar panel (kWh)'] = \
    (G_module * area_of_solar_panel * number_of_solar_panels * efficiency_solar_panel) / (1e3 * 3600 )
print("Last data frame after calculations/n")
# Out:
# Last data frame after calculations/n

# %%
df.sample(10)
# Out:
#              YYYYMMDDHH  average windspeed (m/s)  \
# 304 2024-01-13 17:00:00                       60
# 328 2024-01-14 17:00:00                      100
# 495 2024-01-21 16:00:00                      140
# 398 2024-01-17 15:00:00                       10
# 468 2024-01-20 13:00:00                       90
# 368 2024-01-16 09:00:00                       80
# 241 2024-01-11 02:00:00                       40
# 214 2024-01-09 23:00:00                       70
# 458 2024-01-20 03:00:00                       70
# 282 2024-01-12 19:00:00                       60
#
#      windspeed previous 10 minuten (m/s)  highest windspeed (m/s)  \
# 304                                   60                       80
# 328                                  120                      170
# 495                                  130                      200
# 398                                   10                       20
# 468                                   90                      120
# 368                                   80                      110
# 241                                   30                       60
# 214                                   70                      100
# 458                                   60                      110
# 282                                   50                       80
#
#      temperature in degrees Celcius  global radiation (in J/m^2)  \
# 304                              50                          0.0
# 328                              52                          0.0
# 495                              54                      60000.0
# 398                              14                     130000.0
# 468                              13                     980000.0
# 368                              25                      80000.0
# 241                             -33                          0.0
# 214                             -29                          0.0
# 458                              10                          0.0
# 282                              51                          0.0
#
#      duration of sunshine (h)  cloud cover (-)  \
# 304                       0.0              NaN
# 328                       0.0              NaN
# 495                       0.0              NaN
# 398                       0.0              NaN
# 468                       1.0              NaN
# 368                       0.0              NaN
# 241                       0.0              NaN
# 214                       0.0              NaN
# 458                       0.0              NaN
# 282                       0.0              NaN
#
#      relative humidity (in percentages)  air pressure (Pa)  \
# 304                                  90              10204
# 328                                  83              10061
# 495                                  86              10151
# 398                                  69               9890
# 468                                  73              10269
# 368                                  61              10087
# 241                                  67              10334
# 214                                  53              10320
# 458                                  88              10259
# 282                                  87              10317
#
#      yield solar panel (kWh)
# 304                 0.000000
# 328                 0.000000
# 495                 0.007142
# 398                 0.002988
# 468                 0.131731
# 368                 0.027743
# 241                 0.000000
# 214                 0.000000
# 458                 0.000000
# 282                 0.000000

# %%
value = df.iloc[468]["yield solar panel (kWh)"]  ###when efficiency_solar_panel = 0.18  
print(f"yield solar panel (kWh): {value}")
# Out:
# yield solar panel (kWh): 0.1317310489936

# %%
value = df.iloc[468]["yield solar panel (kWh)"] ###when efficiency_solar_panel = 0.20  
print(f"yield solar panel (kWh): {value}")
# Out:
# yield solar panel (kWh): 0.14636783221511113

# %%
value = df.iloc[468]["yield solar panel (kWh)"] # ## total number of solar panels used [2] and effiency = 0.20
print(f"yield solar panel (kWh): {value}")
# Out:
# yield solar panel (kWh): 0.29273566443022225

# %% [markdown]
# This evaluation demonstrates how changing key parameters influences solar energy yield. In lines 39, increasing the solar panel efficiency led to a higher energy output. In line 42, adding an extra solar panel also increased the total energy generated, as expected.

# %%
visualisation_year = [2024]
visualisation_month = [1]
number_of_weather_station = 330

# %%
# Visualisation parameters
visualisation_day = range(1, number_to_month[visualisation_month[0]][1] + 1)

df_visualisation = df[
    (df['YYYYMMDDHH'].dt.year.isin(visualisation_year)) &
    (df['YYYYMMDDHH'].dt.month.isin(visualisation_month)) &
    (df['YYYYMMDDHH'].dt.day.isin(visualisation_day))
]

# %%
# Initialize plot
fig = plt.figure(figsize = (9, 9))
ax = fig.add_subplot(1, 1, 1, projection = '3d')
plt.style.use('default')
ax.set_box_aspect((1, 1, 0.25))
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.invert_yaxis()
field = 'yield solar panel (kWh)'    
str_ = field + ' in ' + number_to_month[visualisation_month[0]][0]
ax.set_title(str_)
ax.set_xlabel('hours')
ax.set_ylabel('days')
ax.set_zlabel('[kWh]')
# Out:
# Text(0.5, 0, '[kWh]')

# %%
correlation_matrix = df.corr(method='pearson')
print(correlation_matrix['yield solar panel (kWh)'])
# Out:
# YYYYMMDDHH                             0.122016
# average windspeed (m/s)               -0.020125
# windspeed previous 10 minuten (m/s)   -0.035431
# highest windspeed (m/s)               -0.025931
# temperature in degrees Celcius         0.018124
# global radiation (in J/m^2)            0.937808
# duration of sunshine (h)               0.786044
# cloud cover (-)                             NaN
# relative humidity (in percentages)    -0.309678
# air pressure (Pa)                      0.114104
# yield solar panel (kWh)                1.000000
# Name: yield solar panel (kWh), dtype: float64

# %%
plt.figure(figsize=(16, 6))
heatmap=sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
heatmap.set_title('Correlation Heatmap of Solar Parameters and Energy Yield', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# The heatmap analysis reveals that global radiation and duration of sunshine are the most influential factors in determining solar panel yield. These parameters show a strong correlation with energy output, indicating their primary role in solar generation. In the next phase, I plan to store the angle parameters such as tilt and azimuth into a DataFrame and visualize their impact to assess whether panel orientation significantly affects energy yield.
